# %%
from my_libs import *
# Out:
# /home/ken/.local/lib/python2.7/site-packages/pyfolio/pos.py:28: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   ' to position notionals.'

# %%
get_price_data(["AAPL"], method = "intraday")
# Out:
# All price data of Close is actually Adj Close
# ('Finished', u'AAPL')
#        Close           TimeStamp     High      Low     Open    Volume Ticker  \
# 263 281.3600 2020-04-27 11:00:00 283.1500 281.0700 283.1500  11439973   AAPL
# 262 281.8000 2020-04-27 13:00:00 282.1550 281.4800 282.1550  17629169   AAPL
# 261 282.4600 2020-04-27 14:30:00 282.6500 281.9088 281.9800  21223381   AAPL
# 260 281.0700 2020-04-28 11:00:00 284.1000 280.6856 283.9700   9724173   AAPL
# 259 281.1700 2020-04-28 12:00:00 282.3300 280.9400 281.9300  12885969   AAPL
# 258 280.2200 2020-04-28 12:30:00 280.3200 279.3674 279.7600  14632366   AAPL
# 257 281.1650 2020-04-28 14:30:00 282.0400 280.8750 281.0350  19346412   AAPL
# 256 280.8250 2020-04-28 15:00:00 281.4900 280.4900 281.1650  20381664   AAPL
# 255 278.8621 2020-04-28 16:00:00 280.4400 278.2697 280.2500  24899344   AAPL
# 254 287.8250 2020-04-29 11:00:00 289.6299 287.8000 288.9650  12862873   AAPL
# ...

# %%
mongod.update_db_multi_test()
# Out:
# successed GOOG
# MO
