# %%
from my_libs_py3 import *
# Out:
# /Users/ken/.local/lib/python3.8/site-packages/pyfolio/pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(

# %%
mymongo = mongo()
# Out:
# Connection Successful

# %%
sql = '''


select * from all_symbol.screener
limit 1


'''

# %%
data = mymongo.conn.get_data(sql)

# %%
data.columns
# Out:
# Index(['20-Day Simple Moving Average', '200-Day Simple Moving Average',
#        '50-Day Simple Moving Average', '52-Week High', '52-Week Low',
#        'Analyst Recom', 'Average Volume', 'Beta', 'Change', 'Change from Open',
#        'Company', 'Country', 'Current Ratio', 'Dividend Yield', 'EPS (ttm)',
#        'EPS growth past 5 years', 'EPS growth quarter over quarter',
#        'EPS growth this year', 'Forward P/E', 'Gap', 'Gross Margin',
#        'Industry', 'Insider Ownership', 'Insider Transactions',
#        'Institutional Ownership', 'Institutional Transactions',
#        'LT Debt/Equity', 'Market Cap', 'Operating Margin', 'P/B', 'P/Cash',
#        'P/E', 'P/Free Cash Flow', 'P/S', 'PEG', 'Payout Ratio',
#        'Performance (Month)', 'Performance (Quarter)', 'Performance (Week)',
#        'Price', 'Profit Margin', 'Quick Ratio', 'Refresh_Date',
#        'Relative Strength Index (14)', 'Relative Volume',
#        'Sales growth past 5 years', 'Sales growth quarter over quarter',
#        'Sector', 'Shares Outstanding', 'Target Price', 'Ticker',
#        'Total Debt/Equity', 'Volatility (Month)', 'Volume'],
#       dtype='object')

# %%
get_price_data(["bvh"],method = "minute_to_day",robinhood=robingateway())
# Out:
# All price data of Close is actually Adj Close
# Connection Successful
# ('Finished', 'bvh')
#      Close           TimeStamp    High     Low    Open  Volume Ticker    Time  \
# 0  11.2400 2020-11-16 16:00:00 11.2700 11.0600 11.2700   30165    BVH  160000
# 1  11.3300 2020-11-17 16:00:00 11.3700 11.3150 11.3150   14341    BVH  160000
# 2  11.5000 2020-11-18 16:00:00 11.5300 11.4600 11.5300   27870    BVH  160000
# 3  11.4700 2020-11-19 16:00:00 11.7300 11.4700 11.6700   13485    BVH  160000
# 4  11.6150 2020-11-20 16:00:00 11.6150 11.5100 11.5600   21499    BVH  160000
# 5  11.9700 2020-11-23 16:00:00 12.1650 11.9700 12.1400   19740    BVH  160000
# 6  12.9300 2020-11-24 16:00:00 12.9900 12.8700 12.9800   17851    BVH  160000
# 7  13.0900 2020-11-25 16:00:00 13.2200 13.0900 13.2200   10440    BVH  160000
# 8  12.8800 2020-11-27 16:00:00 12.8800 12.8800 12.8800   12675    BVH  160000
# 9  12.7900 2020-11-30 16:00:00 12.8100 12.7100 12.7230    8518    BVH  160000
# 10 12.6928 2020-12-01 16:00:00 12.8600 12.6811 12.8600   10497    BVH  160000
# 11 12.6000 2020-12-02 16:00:00 12.6000 12.6000 12.6000   12589    BVH  160000
# 12 12.7000 2020-12-03 16:00:00 12.7700 12.6600 12.6600    5014    BVH  160000
# 13 13.7600 2020-12-04 16:00:00 13.9300 13.5000 13.5000   32473    BVH  160000
# 14 13.7500 2020-12-07 16:00:00 13.9800 13.7500 13.9800   32533    BVH  160000
# 15 13.8300 2020-12-08 16:00:00 13.9500 13.8300 13.9300   24403    BVH  160000
# 49 12.9800 2021-01-28 16:00:00 12.9850 12.8900 12.9800   44532    BVH  160000
# 50 13.1300 2021-01-29 16:00:00 13.2700 13.0000 13.0100   26102    BVH  160000
#
#     Return  Fwd_Return
# 0      nan      0.0080
# 1   0.0079      0.0149
# 2   0.0148     -0.0026
# 3  -0.0026      0.0126
# 4   0.0125      0.0301
# 5   0.0297      0.0771
# 6   0.0742      0.0123
# 7   0.0122     -0.0162
# 8  -0.0163     -0.0070
# 9  -0.0070     -0.0076
# 10 -0.0077     -0.0073
# 11 -0.0074      0.0079
# 12  0.0079      0.0802
# 13  0.0770     -0.0007
# 14 -0.0007      0.0058
# 15  0.0058      0.0043
# 16  0.0043     -0.0094
# 17 -0.0095     -0.0094
# 18 -0.0095     -0.0531
# 19 -0.0545      0.0557
# 20  0.0542     -0.0361
# 21 -0.0368     -0.0426
# 22 -0.0435      0.0289
# 23  0.0285     -0.0101
# 24 -0.0101     -0.0117
# 25 -0.0118      0.0187
# 26  0.0185     -0.0054
# 27 -0.0054     -0.0283
# 28 -0.0287     -0.0101
# 29 -0.0101      0.0622
# 30  0.0603      0.0262
# 31  0.0258     -0.0664
# 32 -0.0686      0.0110
# 33  0.0109      0.0888
# 34  0.0849     -0.0641
# 35 -0.0662     -0.0286
# 36 -0.0290      0.0000
# 37  0.0000      0.0688
# 38  0.0665     -0.0870
# 39 -0.0909      0.0383
# 40  0.0376     -0.0288
# 41 -0.0292      0.0087
# 42  0.0086      0.0023
# 43  0.0023      0.0163
# 44  0.0161     -0.0008
# 45 -0.0008      0.0130
# 46  0.0129      0.0053
# 47  0.0053     -0.0191
# 48 -0.0192     -0.0008
# 49 -0.0008      0.0115
# 50  0.0114         nan

# %%
plot_ticker("bvh",method = "day",robinhood=robingateway())
# Out:
# All price data of Close is actually Adj Close
# Connection Successful
# ('Finished', 'bvh')

# %%
i = "ai"
trade_scale = "day"

# %%
first = momentum_best_day(i,robinhood=robingateway(),method =trade_scale).iloc[0]
end_value,sharpratio, last_trade, last_price, max_return,min_return = momentum_backtest(i,first["Lookback"],first["Holding"],robinhood=robingateway(),method = trade_scale)
# Out:
# All price data of Close is actually Adj Close
# Connection Successful
# ('Finished', 'ai')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-5f8f0c4426e8> in <module>
# ----> 1 first = momentum_best_day(i,robinhood=robingateway(),method =trade_scale).iloc[0]
#       2 trade_scale = "day"
#       3 end_value,sharpratio, last_trade, last_price, max_return,min_return = momentum_backtest(i,first["Lookback"],first["Holding"],robinhood=robingateway(),method = trade_scale)
#
# ~/notebook/My_Trader2.0/my_libs_py3/my_strategies.py in momentum_best_day(ticker, robinhood, method)
#    1004
#    1005             ret_post= ret_post.iloc[shorter:]
# -> 1006             corr,p_value = stats.pearsonr(ret_pre,ret_post)
#    1007             result = result.append({"Lookback":lookback,"Holding":holding,"Correlation":corr,"P_Value":p_value},ignore_index=True)
#    1008             result.columns = ["Lookback","Holding","Correlation","P_Value"]
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py in pearsonr(x, y)
#    3836
#    3837     if n < 2:
# -> 3838         raise ValueError('x and y must have length at least 2.')
#    3839
#    3840     x = np.asarray(x)
#
# ValueError: x and y must have length at least 2.

# %%
i = "BVH"
back_day = 10

# %%
sql = '''

select
* 
from stocks_10minute.{}
where hour(timestamp) = 16

'''.format(i)

temp = mongodb.conn.get_data(sql)
                    
#index= pd.MultiIndex.from_product([[i],temp.index])
#temp=pd.DataFrame(data=temp.values,index=index,columns=temp.columns)
temp["Return"]= (temp.Close.diff(1)/temp.Close)
temp["Fwd_Return"] = np.log(temp.Close.shift(-1)/temp.Close)
#temp = temp.reset_index()
if len(temp)< back_day*(2.0/7.0):
    print ("Data rows not enough for the back days")
    raise
if last_record :
    price = price.append(temp.iloc[-1])
else:
    price = price.append(temp)

#price = price.drop("level_0",axis=1)
#price = price.drop("level_1",axis=1)

print(("Finished", i))
trial = 3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-4612e0419cc3> in <module>
#      18     print ("Data rows not enough for the back days")
#      19     raise
# ---> 20 if last_record :
#      21     price = price.append(temp.iloc[-1])
#      22 else:
#
# NameError: name 'last_record' is not defined

# %%
data.tail(10)
# Out:
#    TimeStamp        Open        High         Low       Close    adjClose  \
# 9 2021-01-15     12.6800     12.9700     12.5200     12.7000     12.7000
# 8 2021-01-19     12.8700     13.3100     12.7300     13.0100     13.0100
# 7 2021-01-20     12.8900     13.1500     12.7000     12.7600     12.7600
# 6 2021-01-21     12.8500     13.1700     12.5500     12.8500     12.8500
# 5 2021-01-22     12.6000     13.0150     12.4000     12.8400     12.8400
# 4 2021-01-25 64,600.0000 64,700.0000 64,000.0000 64,000.0000 64,000.0000
# 3 2021-01-26 63,800.0000 64,000.0000 60,000.0000 60,500.0000 60,500.0000
# 2 2021-01-27 59,200.0000 60,800.0000 57,200.0000 58,000.0000 58,000.0000
# 1 2021-01-28 54,500.0000 57,000.0000 54,000.0000 54,000.0000 54,000.0000
# 0 2021-01-29 51,000.0000 57,200.0000 51,000.0000 56,500.0000 56,500.0000
#
#         Volume  unadjustedVolume      change  changePercent        vwap  \
# 9  27,000.0000       27,000.0000      0.0200         0.1580     12.7300
# 8  15,900.0000       15,900.0000      0.1400         1.0880     13.0167
# 7  35,700.0000       35,700.0000     -0.1300        -1.0090     12.8700
# 6  16,800.0000       16,800.0000      0.0000         0.0000     12.8567
# 5  35,455.0000       35,455.0000      0.2400         1.9050     12.7517
# 4  69,540.0000       69,540.0000   -600.0000        -0.9290 64,233.3333
# 3 116,690.0000      116,690.0000 -3,300.0000        -5.1720 61,500.0000
# 2  93,100.0000       93,100.0000 -1,200.0000        -2.0270 58,666.6667
# 1 125,650.0000      125,650.0000   -500.0000        -0.9170 55,000.0000
# 0 106,950.0000      106,950.0000  5,500.0000        10.7840 54,900.0000
#
#             label  changeOverTime Ticker
# 9  January 15, 21          0.0016    BVH
# 8  January 19, 21          0.0109    BVH
# 7  January 20, 21         -0.0101    BVH
# 6  January 21, 21          0.0000    BVH
# 5  January 22, 21          0.0191    BVH
# 4  January 25, 21         -0.0093    BVH
# 3  January 26, 21         -0.0517    BVH
# 2  January 27, 21         -0.0203    BVH
# 1  January 28, 21         -0.0092    BVH
# 0  January 29, 21          0.1078    BVH
