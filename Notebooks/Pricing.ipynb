# %%
from my_libs import *
# Out:
# /home/ken/.local/lib/python2.7/site-packages/pyfolio/pos.py:28: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   ' to position notionals.'

# %%
key_metrics("AAPL","quarter")
# Out:
#     averageInventory  averagePayables  averageReceivables  bookValuePerShare  \
# 0         3715500000      38766000000         18346000000            17.8744
# 1         4097000000      45111000000         20970000000            20.2786
# 2         4101500000      45673500000         21948000000            19.5953
# 3         3726000000      37113000000         17559000000            20.6979
# 4         4490500000      37777000000         18027500000            22.4997
# 5         4542500000      44702000000         19523500000            24.8937
# 6         4026500000      50499500000         22078000000            21.6224
# 7         5016500000      41800000000         17537000000            22.9593
# 8         5879500000      39711000000         17647000000            25.0308
# 9         4259000000      54048000000         22205000000            27.4208
# 10        4476000000      47080000000         19422000000            25.6931
# ...

# %%
op_pricing = Option(OptionExerciseType.AMERICAN,286,287,0.5,0.02)

# %%
op_pricing.run_model()
# Out:
# {'delta': -0.5952689981069023,
#  'gamma': 0.09591868800571654,
#  'rho': -78.86857581862694,
#  'theta': -1.6032097329368722,
#  'value': 2.1620221843403327,
#  'vega': 75.35076585014377}

# %%
realtimequote("^vix")["price"].iloc[0]
# Out:
# 31.89
