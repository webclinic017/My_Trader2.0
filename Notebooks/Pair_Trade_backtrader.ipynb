# %%
from my_libs import *


# Defining datafeed object



def backtest_pair(i,j, strategy, capital = 2000, method = "day",back_day = 80,window = 3 ):

#     try:
    robinhood = robingateway()
    
    price1 = get_price_data([i], method=method,robinhood=robinhood,back_day=back_day )
    price1 = price1.set_index("TimeStamp")
    price1.loc[price1.Open == 0,"Open"] = np.NaN
    

    price2 = get_price_data([j], method=method,robinhood=robinhood,back_day=back_day )
    price2 = price2.set_index("TimeStamp")
    price_table = pd.DataFrame()
    #--------------------------------------------------------------
#     return price1, price2
    


    price1.loc[:,"log_ret"] = log(price1.Close / price1.Close.shift(1))
    price2.loc[:,"log_ret"] = log(price1.Close / price2.Close.shift(1))


    price1.loc[:, "log_ret_mv"] = price1.log_ret.rolling(window).mean()
    price2.loc[:, "log_ret_mv"] = price2.log_ret.rolling(window).mean()

    price1 = price1.fillna(method="bfill")
    price2 = price2.fillna(method="bfill")
    
    price_table.loc[:,"relative"] = price1.log_ret_mv / price2.log_ret_mv

    price_table.loc[:,"relative_mv"] = price_table["relative"].rolling(window, min_periods=window).mean()
    price_table["relative_mv"] = abs(price_table["relative_mv"])
   

    for i in range(len(price1)-window):
        i += window
        price_table.loc[price_table.iloc[i].name,"slope"] = stats.linregress(price1.log_ret.iloc[:i],price2.log_ret.iloc[:i])[0]





    price1.loc[:,"volatility"] = price1.log_ret.rolling(window,min_periods=window-5).std()
    price2.loc[:,"volatility"] = price2.log_ret.rolling(window,min_periods=window-5).std()


    price_table["z_score"] =( price_table["relative"]-price_table["relative_mv"])/price_table.relative.std()
    price_table = price_table.fillna(method="bfill")




    cerebro = bt.Cerebro()
    cerebro.addstrategy(strategy)
    cerebro.broker.setcommission(commission=0.0)



    # Create a Data Feed
    data1 = datapairtrade(dataname=price1)
    data2 = datapairtrade(dataname=price2)
    data3 = datapairtrade_table(dataname=price_table)


    cerebro.adddata(data1)
    cerebro.adddata(data2)
    cerebro.adddata(data3)
    cerebro.broker.setcash(capital)
    #cerebro.addanalyzer(bt.analyzers.PyFolio)
    init = cerebro.broker.getvalue()
    #print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())
    cerebro.run()
    post = cerebro.broker.getvalue()
    if post > init:
        print ("Good Trade")

    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
#     cerebro.plot()
            
#     except Exception as e:
#         print (e)
#         return

class pair_trade(bt.Strategy):
    
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log('BUY EXECUTED, price: %.2f, size: %d' % (order.executed.price, order.executed.size))
            elif order.issell():
                self.log('SELL EXECUTED, %.2f, size: %d' % (order.executed.price,order.executed.size))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        # Write down: no pending order
        self.order = None

    
    def log(self, txt, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.data.datetime.date(0)
        print('%s, %s' % (dt, txt))
    
    
    def buy_line(self,data_frame):
        data_frame = data_frame.slope
        if data_frame>0.5:
            return -1.25
        elif data_frame>0.75:
            return -1.75
        elif data_frame:
            return -2.25
        elif data_frame<-0.75:
            return -2.75
        else:
            return -2
    def sell_line(self,data_frame):
        data_frame = data_frame.slope
        if data_frame>0.5:
            return 1.25
        elif data_frame>0.75:
            return 1.75
        elif data_frame:
            return 2.25
        elif data_frame<-0.75:
            return 2.75
        else:
            return 2


    def __init__(self):
        self.buy_lines = None
        self.sell_lines = None
        self.currentsell = 0
        self.currentbuy = 0
        #self.adxr = bt.indicators.ADXR()
        #self.cci = bt.indicators.CCI()
        #self.macd = bt.talib.MACD(self.data.Close, fastperiod=12, slowperiod=26, signalperiod=9)
        #self.mfi = bt.talib.MFI(self.data.High, self.data.Low, self.data.Close, self.data.Volume,timeperiod=14)
        #self.rocp = bt.talib.ROCP(self.data.Close, timeperiod=10)
       
        

    def next(self):
        self.buy_lines = self.buy_line(self.datas[2])
        self.sell_lines = self.sell_line(self.datas[2])
        #print (str(self.datas[2].datetime.date(0)) +" Z-score:" + str(self.datas[2].slope[0]) + " buy line: " + str(self.buy_lines) + " sell line: "+str(self.sell_lines))
   
        if self.datas[2].z_score < self.buy_lines:
            size1 = np.ceil(((self.broker.getcash()/2)/(1+self.datas[2].relative_mv[0])/self.datas[0].close[0]))
            size2 = np.ceil(((self.broker.getcash()/2) \
                                /(1+self.datas[2].relative_mv)*self.datas[2].relative_mv[0]/self.datas[1].close[0]))
            if self.getposition(self.datas[0]).size != size1:
                self.log("Close buy position: %d" % (self.getposition(self.datas[0]).size))
                self.close(data=self.datas[0])
                self.buy(size = size1,data = self.datas[0])
         
                
                
            if self.getposition(self.datas[1]).size != size2:
                self.log("Close sell position: %d" % (self.getposition(self.datas[1]).size))
                self.close(data=self.datas[1])
                
                self.buy(size = size2 ,data = self.datas[1]) # long only, change to sell when short available
                
                
                
            self.currentsell = size2

            self.log("Buy signal, Cash left:  %.2f , buy stock1: %d sell stock2:  %d"  % (self.broker.getcash(),size1,size2 ))
                
        if self.datas[2].z_score > self.sell_lines:
                
            size1 = np.ceil(((self.broker.getcash()/2)/(1+self.datas[2].relative_mv[0])/self.datas[0].close[0]))
            size2 = np.ceil(((self.broker.getcash()/2)\
                               /(1+self.datas[2].relative_mv)*self.datas[2].relative_mv[0]/self.datas[1].close[0])) 
            
            if self.getposition(self.datas[0]).size > size1:
                self.log("Close sell position: %d" % (self.getposition(self.datas[0]).size))
                self.close(data=self.datas[0])
                
                self.buy(size = size1 ,data = self.datas[0]) # long only, change to sell when short available
        
          
            if self.getposition(self.datas[1]).size != size2:
                self.log("Close buy position: %d" % (self.getposition(self.datas[1]).size))
                self.close(data=self.datas[1])
                
                self.buy(size = size2,data = self.datas[1])
           
            self.log("Buy signal, Cash left:  %.2f , sell stock1: %d buy stock2:  %d "  % (self.broker.getcash(),size1,size2 ))
        
i = "SPY"
j="VIXY"
backtest_pair(i,j,pair_trade,back_day = 80,method = "self_minute")
# Out:
# All price data of Close is actually Adj Close
# Connection Successful
# ('Finished', 'SPY')
# All price data of Close is actually Adj Close
# Connection Successful
# ('Finished', 'VIXY')
# 2019-08-30, Close buy position: 0
# 2019-08-30, Close sell position: 0
# 2019-08-30, Buy signal, Cash left:  2000.00 , buy stock1: 4 sell stock2:  1
# 2019-08-30, BUY EXECUTED, price: 291.72, size: 4
# 2019-08-30, BUY EXECUTED, price: 22.36, size: 1
# 2019-08-30, Close buy position: 4
# 2019-08-30, Buy signal, Cash left:  810.76 , buy stock1: 2 sell stock2:  1
# 2019-08-30, SELL EXECUTED, 291.72, size: -4
# 2019-08-30, BUY EXECUTED, price: 291.72, size: 2
# 2019-08-30, Close buy position: 2
# 2019-08-30, Buy signal, Cash left:  1394.20 , buy stock1: 3 sell stock2:  1
# 2019-08-30, SELL EXECUTED, 291.72, size: -2
# 2019-08-30, BUY EXECUTED, price: 291.72, size: 3
# 2019-08-30, Close buy position: 3
# 2019-08-30, Buy signal, Cash left:  1102.48 , buy stock1: 2 sell stock2:  1
# 2019-08-30, SELL EXECUTED, 291.72, size: -3
# 2019-08-30, BUY EXECUTED, price: 291.72, size: 2
# 2019-08-30, Close buy position: 2
# 2019-08-30, Buy signal, Cash left:  1394.20 , buy stock1: 3 sell stock2:  1
# 2019-08-30, SELL EXECUTED, 291.72, size: -2
# 2019-08-30, BUY EXECUTED, price: 291.72, size: 3
# 2019-08-30, Close buy position: 3
# 2019-08-30, Buy signal, Cash left:  1102.48 , buy stock1: 2 sell stock2:  1
# 2019-08-30, SELL EXECUTED, 291.72, size: -3
# 2019-08-30, BUY EXECUTED, price: 291.72, size: 2
# 2019-09-03, Close buy position: 2
# 2019-09-03, Buy signal, Cash left:  1394.20 , buy stock1: 3 sell stock2:  1
# 2019-09-03, SELL EXECUTED, 290.57, size: -2
# 2019-09-03, BUY EXECUTED, price: 290.57, size: 3
# 2019-09-03, Close buy position: 3
# 2019-09-03, Buy signal, Cash left:  1103.63 , buy stock1: 2 sell stock2:  1
# 2019-09-03, SELL EXECUTED, 290.57, size: -3
# 2019-09-03, BUY EXECUTED, price: 290.57, size: 2
# 2019-09-03, Close buy position: 2
# 2019-09-03, Buy signal, Cash left:  1394.20 , buy stock1: 3 sell stock2:  1
# 2019-09-03, SELL EXECUTED, 290.57, size: -2
# 2019-09-03, BUY EXECUTED, price: 290.57, size: 3
# 2019-09-05, Close sell position: 3
# 2019-09-05, Buy signal, Cash left:  1103.63 , sell stock1: 2 buy stock2:  1
# 2019-09-05, SELL EXECUTED, 296.79, size: -3
# 2019-09-05, BUY EXECUTED, price: 296.79, size: 2
# 2019-09-05, Buy signal, Cash left:  1400.42 , sell stock1: 3 buy stock2:  1
# 2019-09-05, Close buy position: 2
# 2019-09-05, Buy signal, Cash left:  1400.42 , buy stock1: 3 sell stock2:  1
# 2019-09-05, SELL EXECUTED, 296.79, size: -2
# 2019-09-05, BUY EXECUTED, price: 296.79, size: 3
# 2019-09-09, Close buy position: 3
# 2019-09-09, Buy signal, Cash left:  1103.63 , buy stock1: 2 sell stock2:  1
# 2019-09-09, SELL EXECUTED, 299.14, size: -3
# 2019-09-09, BUY EXECUTED, price: 299.14, size: 2
# 2019-09-10, Close buy position: 2
# 2019-09-10, Buy signal, Cash left:  1402.77 , buy stock1: 3 sell stock2:  1
# 2019-09-10, SELL EXECUTED, 299.14, size: -2
# 2019-09-10, BUY EXECUTED, price: 299.14, size: 3
# 2019-09-10, Close buy position: 3
# 2019-09-10, Buy signal, Cash left:  1103.63 , buy stock1: 2 sell stock2:  1
# 2019-09-10, SELL EXECUTED, 297.36, size: -3
# 2019-09-10, BUY EXECUTED, price: 297.36, size: 2
# 2019-09-10, Close buy position: 2
# 2019-09-10, Buy signal, Cash left:  1400.99 , buy stock1: 3 sell stock2:  1
# 2019-09-10, SELL EXECUTED, 297.36, size: -2
# 2019-09-10, BUY EXECUTED, price: 297.36, size: 3
# 2019-09-16, Close buy position: 3
# 2019-09-16, Buy signal, Cash left:  1103.63 , buy stock1: 2 sell stock2:  1
# 2019-09-16, SELL EXECUTED, 299.84, size: -3
# 2019-09-16, BUY EXECUTED, price: 299.84, size: 2
# 2019-09-18, Close buy position: 2
# 2019-09-18, Buy signal, Cash left:  1403.47 , buy stock1: 3 sell stock2:  1
# 2019-09-18, SELL EXECUTED, 300.49, size: -2
# 2019-09-18, BUY EXECUTED, price: 300.49, size: 3
# 2019-09-20, Close buy position: 3
# 2019-09-20, Buy signal, Cash left:  1102.98 , buy stock1: 2 sell stock2:  1
# 2019-09-20, SELL EXECUTED, 300.36, size: -3
# 2019-09-20, BUY EXECUTED, price: 300.36, size: 2
# 2019-09-20, Close buy position: 2
# 2019-09-20, Buy signal, Cash left:  1403.34 , buy stock1: 3 sell stock2:  1
# 2019-09-20, SELL EXECUTED, 300.36, size: -2
# 2019-09-20, BUY EXECUTED, price: 300.36, size: 3
# 2019-09-20, Close buy position: 3
# 2019-09-20, Buy signal, Cash left:  1102.98 , buy stock1: 2 sell stock2:  1
# 2019-09-20, SELL EXECUTED, 300.36, size: -3
# 2019-09-20, BUY EXECUTED, price: 300.36, size: 2
# 2019-09-24, Close buy position: 2
# 2019-09-24, Buy signal, Cash left:  1403.34 , buy stock1: 3 sell stock2:  1
# 2019-09-24, SELL EXECUTED, 299.41, size: -2
# 2019-09-24, BUY EXECUTED, price: 299.41, size: 3
# 2019-09-24, Close buy position: 3
# 2019-09-24, Buy signal, Cash left:  1103.93 , buy stock1: 2 sell stock2:  1
# 2019-09-24, SELL EXECUTED, 299.41, size: -3
# 2019-09-24, BUY EXECUTED, price: 299.41, size: 2
# 2019-09-24, Close buy position: 2
# 2019-09-24, Buy signal, Cash left:  1403.34 , buy stock1: 3 sell stock2:  1
# 2019-09-24, SELL EXECUTED, 299.41, size: -2
# 2019-09-24, BUY EXECUTED, price: 299.41, size: 3
# 2019-09-24, Close buy position: 3
# 2019-09-24, Buy signal, Cash left:  1103.93 , buy stock1: 2 sell stock2:  1
# 2019-09-24, SELL EXECUTED, 299.41, size: -3
# 2019-09-24, BUY EXECUTED, price: 299.41, size: 2
# 2019-09-24, Close buy position: 2
# 2019-09-24, Buy signal, Cash left:  1403.34 , buy stock1: 3 sell stock2:  1
# 2019-09-24, SELL EXECUTED, 299.41, size: -2
# 2019-09-24, BUY EXECUTED, price: 299.41, size: 3
# 2019-09-24, Close buy position: 3
# 2019-09-24, Buy signal, Cash left:  1103.93 , buy stock1: 2 sell stock2:  1
# 2019-09-24, SELL EXECUTED, 299.41, size: -3
# 2019-09-24, BUY EXECUTED, price: 299.41, size: 2
# 2019-09-26, Close buy position: 2
# 2019-09-26, Buy signal, Cash left:  1403.34 , buy stock1: 3 sell stock2:  1
# 2019-09-26, SELL EXECUTED, 297.63, size: -2
# 2019-09-26, BUY EXECUTED, price: 297.63, size: 3
# 2019-09-27, Close buy position: 3
# 2019-09-27, Buy signal, Cash left:  1105.71 , buy stock1: 2 sell stock2:  1
# 2019-09-27, SELL EXECUTED, 297.83, size: -3
# 2019-09-27, BUY EXECUTED, price: 297.83, size: 2
# 2019-09-27, Close buy position: 2
# 2019-09-27, Buy signal, Cash left:  1403.54 , buy stock1: 3 sell stock2:  1
# 2019-09-27, SELL EXECUTED, 297.83, size: -2
# 2019-09-27, BUY EXECUTED, price: 297.83, size: 3
# 2019-09-27, Close buy position: 3
# 2019-09-27, Buy signal, Cash left:  1105.71 , buy stock1: 2 sell stock2:  1
# 2019-09-27, SELL EXECUTED, 297.83, size: -3
# 2019-09-27, BUY EXECUTED, price: 297.83, size: 2
# 2019-09-27, Close buy position: 2
# 2019-09-27, Buy signal, Cash left:  1403.54 , buy stock1: 3 sell stock2:  1
# 2019-09-27, SELL EXECUTED, 297.83, size: -2
# 2019-09-27, BUY EXECUTED, price: 297.83, size: 3
# 2019-10-01, Close buy position: 3
# 2019-10-01, Buy signal, Cash left:  1105.71 , buy stock1: 2 sell stock2:  1
# 2019-10-01, SELL EXECUTED, 297.74, size: -3
# 2019-10-01, BUY EXECUTED, price: 297.74, size: 2
# 2019-10-01, Close buy position: 2
# 2019-10-01, Buy signal, Cash left:  1403.45 , buy stock1: 3 sell stock2:  1
# 2019-10-01, SELL EXECUTED, 297.74, size: -2
# 2019-10-01, BUY EXECUTED, price: 297.74, size: 3
# 2019-10-01, Close buy position: 3
# 2019-10-01, Buy signal, Cash left:  1105.71 , buy stock1: 2 sell stock2:  1
# 2019-10-01, SELL EXECUTED, 297.74, size: -3
# 2019-10-01, BUY EXECUTED, price: 297.74, size: 2
# 2019-10-01, Close buy position: 2
# 2019-10-01, Buy signal, Cash left:  1403.45 , buy stock1: 3 sell stock2:  1
# 2019-10-01, SELL EXECUTED, 297.74, size: -2
# 2019-10-01, BUY EXECUTED, price: 297.74, size: 3
# 2019-10-01, Close buy position: 3
# 2019-10-01, Buy signal, Cash left:  1105.71 , buy stock1: 2 sell stock2:  1
# 2019-10-01, SELL EXECUTED, 297.74, size: -3
# 2019-10-01, BUY EXECUTED, price: 297.74, size: 2
# 2019-10-01, Close buy position: 2
# 2019-10-01, Buy signal, Cash left:  1403.45 , buy stock1: 3 sell stock2:  1
# 2019-10-01, SELL EXECUTED, 297.74, size: -2
# 2019-10-01, BUY EXECUTED, price: 297.74, size: 3
# 2019-10-02, Close buy position: 3
# 2019-10-02, Buy signal, Cash left:  1105.71 , buy stock1: 2 sell stock2:  1
# 2019-10-02, SELL EXECUTED, 291.50, size: -3
# 2019-10-02, BUY EXECUTED, price: 291.50, size: 2
# 2019-10-02, Close buy position: 2
# 2019-10-02, Buy signal, Cash left:  1397.21 , buy stock1: 3 sell stock2:  1
# 2019-10-02, SELL EXECUTED, 291.50, size: -2
# 2019-10-02, BUY EXECUTED, price: 291.50, size: 3
# 2019-10-02, Close buy position: 3
# 2019-10-02, Buy signal, Cash left:  1105.71 , buy stock1: 2 sell stock2:  1
# 2019-10-02, SELL EXECUTED, 291.50, size: -3
# 2019-10-02, BUY EXECUTED, price: 291.50, size: 2
# 2019-10-02, Close buy position: 2
# 2019-10-02, Buy signal, Cash left:  1397.21 , buy stock1: 3 sell stock2:  1
# 2019-10-02, SELL EXECUTED, 291.50, size: -2
# 2019-10-02, BUY EXECUTED, price: 291.50, size: 3
# 2019-10-02, Close buy position: 3
# 2019-10-02, Buy signal, Cash left:  1105.71 , buy stock1: 2 sell stock2:  1
# 2019-10-02, SELL EXECUTED, 291.50, size: -3
# 2019-10-02, BUY EXECUTED, price: 291.50, size: 2
# 2019-10-02, Close buy position: 2
# 2019-10-02, Buy signal, Cash left:  1397.21 , buy stock1: 3 sell stock2:  1
# 2019-10-02, SELL EXECUTED, 291.50, size: -2
# 2019-10-02, BUY EXECUTED, price: 291.50, size: 3
# 2019-10-03, Close buy position: 3
# 2019-10-03, Buy signal, Cash left:  1105.71 , buy stock1: 2 sell stock2:  1
# 2019-10-03, SELL EXECUTED, 287.81, size: -3
# 2019-10-03, BUY EXECUTED, price: 287.81, size: 2
# 2019-10-03, Close buy position: 2
# 2019-10-03, Buy signal, Cash left:  1393.52 , buy stock1: 3 sell stock2:  1
# 2019-10-03, SELL EXECUTED, 287.81, size: -2
# 2019-10-03, BUY EXECUTED, price: 287.81, size: 3
# 2019-10-03, Close sell position: 3
# 2019-10-03, Buy signal, Cash left:  1105.71 , sell stock1: 2 buy stock2:  1
# 2019-10-03, SELL EXECUTED, 287.81, size: -3
# 2019-10-03, BUY EXECUTED, price: 287.81, size: 2
# 2019-10-07, Close buy position: 2
# 2019-10-07, Buy signal, Cash left:  1393.52 , buy stock1: 3 sell stock2:  1
# 2019-10-07, SELL EXECUTED, 293.47, size: -2
# 2019-10-07, BUY EXECUTED, price: 293.47, size: 3
# 2019-10-08, Close buy position: 3
# 2019-10-08, Buy signal, Cash left:  1100.05 , buy stock1: 2 sell stock2:  1
# 2019-10-08, SELL EXECUTED, 291.04, size: -3
# 2019-10-08, BUY EXECUTED, price: 291.04, size: 2
# 2019-10-08, Close buy position: 2
# 2019-10-08, Buy signal, Cash left:  1391.09 , buy stock1: 3 sell stock2:  1
# 2019-10-08, SELL EXECUTED, 291.04, size: -2
# 2019-10-08, BUY EXECUTED, price: 291.04, size: 3
# 2019-10-08, Close buy position: 3
# 2019-10-08, Buy signal, Cash left:  1100.05 , buy stock1: 2 sell stock2:  1
# 2019-10-08, SELL EXECUTED, 291.04, size: -3
# 2019-10-08, BUY EXECUTED, price: 291.04, size: 2
# 2019-10-08, Close buy position: 2
# 2019-10-08, Buy signal, Cash left:  1391.09 , buy stock1: 3 sell stock2:  1
# 2019-10-08, SELL EXECUTED, 291.04, size: -2
# 2019-10-08, BUY EXECUTED, price: 291.04, size: 3
# 2019-10-08, Close buy position: 3
# 2019-10-08, Buy signal, Cash left:  1100.05 , buy stock1: 2 sell stock2:  1
# 2019-10-08, SELL EXECUTED, 291.04, size: -3
# 2019-10-08, BUY EXECUTED, price: 291.04, size: 2
# 2019-10-08, Close buy position: 2
# 2019-10-08, Buy signal, Cash left:  1391.09 , buy stock1: 3 sell stock2:  1
# 2019-10-08, SELL EXECUTED, 291.04, size: -2
# 2019-10-08, BUY EXECUTED, price: 291.04, size: 3
# 2019-10-08, Close buy position: 3
# 2019-10-08, Buy signal, Cash left:  1100.05 , buy stock1: 2 sell stock2:  1
# 2019-10-08, SELL EXECUTED, 291.04, size: -3
# 2019-10-08, BUY EXECUTED, price: 291.04, size: 2
# 2019-10-08, Close buy position: 2
# 2019-10-08, Buy signal, Cash left:  1391.09 , buy stock1: 3 sell stock2:  1
# 2019-10-08, SELL EXECUTED, 291.04, size: -2
# 2019-10-08, BUY EXECUTED, price: 291.04, size: 3
# 2019-10-08, Close buy position: 3
# 2019-10-08, Buy signal, Cash left:  1100.05 , buy stock1: 2 sell stock2:  1
# 2019-10-08, SELL EXECUTED, 291.04, size: -3
# 2019-10-08, BUY EXECUTED, price: 291.04, size: 2
# 2019-10-09, Buy signal, Cash left:  1391.09 , sell stock1: 3 buy stock2:  1
# 2019-10-09, Close buy position: 2
# 2019-10-09, Buy signal, Cash left:  1391.09 , buy stock1: 3 sell stock2:  1
# 2019-10-09, SELL EXECUTED, 290.75, size: -2
# 2019-10-09, BUY EXECUTED, price: 290.75, size: 3
# 2019-10-09, Close buy position: 3
# 2019-10-09, Buy signal, Cash left:  1100.34 , buy stock1: 2 sell stock2:  1
# 2019-10-09, SELL EXECUTED, 290.75, size: -3
# 2019-10-09, BUY EXECUTED, price: 290.75, size: 2
# 2019-10-11, Buy signal, Cash left:  1391.09 , sell stock1: 3 buy stock2:  1
# 2019-10-11, Close buy position: 2
# 2019-10-11, Buy signal, Cash left:  1391.09 , buy stock1: 3 sell stock2:  1
# 2019-10-11, SELL EXECUTED, 296.27, size: -2
# 2019-10-11, BUY EXECUTED, price: 296.27, size: 3
# 2019-10-11, Close buy position: 3
# 2019-10-11, Buy signal, Cash left:  1094.82 , buy stock1: 2 sell stock2:  1
# 2019-10-11, SELL EXECUTED, 296.27, size: -3
# 2019-10-11, BUY EXECUTED, price: 296.27, size: 2
# 2019-10-11, Close buy position: 2
# 2019-10-11, Buy signal, Cash left:  1391.09 , buy stock1: 3 sell stock2:  1
# 2019-10-11, SELL EXECUTED, 296.27, size: -2
# 2019-10-11, BUY EXECUTED, price: 296.27, size: 3
# 2019-10-11, Close buy position: 3
# 2019-10-11, Buy signal, Cash left:  1094.82 , buy stock1: 2 sell stock2:  1
# 2019-10-11, SELL EXECUTED, 296.27, size: -3
# 2019-10-11, BUY EXECUTED, price: 296.27, size: 2
# 2019-10-15, Close buy position: 2
# 2019-10-15, Buy signal, Cash left:  1391.09 , buy stock1: 3 sell stock2:  1
# 2019-10-15, SELL EXECUTED, 297.10, size: -2
# 2019-10-15, BUY EXECUTED, price: 297.10, size: 3
# 2019-10-18, Close buy position: 3
# 2019-10-18, Buy signal, Cash left:  1093.99 , buy stock1: 2 sell stock2:  1
# 2019-10-18, SELL EXECUTED, 298.69, size: -3
# 2019-10-18, BUY EXECUTED, price: 298.69, size: 2
# 2019-10-22, Close buy position: 2
# 2019-10-22, Buy signal, Cash left:  1392.68 , buy stock1: 3 sell stock2:  1
# 2019-10-22, SELL EXECUTED, 300.58, size: -2
# 2019-10-22, BUY EXECUTED, price: 300.58, size: 3
# 2019-10-31, Close buy position: 3
# 2019-10-31, Buy signal, Cash left:  1092.10 , buy stock1: 2 sell stock2:  1
# 2019-10-31, SELL EXECUTED, 304.13, size: -3
# 2019-10-31, BUY EXECUTED, price: 304.13, size: 2
# 2019-10-31, Close buy position: 2
# 2019-10-31, Buy signal, Cash left:  1396.23 , buy stock1: 3 sell stock2:  1
# 2019-10-31, SELL EXECUTED, 304.13, size: -2
# 2019-10-31, BUY EXECUTED, price: 304.13, size: 3
# 2019-10-31, Close buy position: 3
# 2019-10-31, Buy signal, Cash left:  1092.10 , buy stock1: 2 sell stock2:  1
# 2019-10-31, SELL EXECUTED, 304.13, size: -3
# 2019-10-31, BUY EXECUTED, price: 304.13, size: 2
# Good Trade
# Final Portfolio Value: 2034.13
