# %%
from my_libs import *
# Out:
# /home/ken/.local/lib/python2.7/site-packages/pyfolio/pos.py:28: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   ' to position notionals.'

# %%
data = pd.read_csv("/home/ken/Downloads/City_zhvi_uc_sfr_tier_0.33_0.67_sm_sa_mon.csv")

# %%
for i in data.index:
        
    data.loc[i,"RegionName_State"] = data.loc[i].RegionName + "_"+data.loc[i].State

# %%
data = data.drop(["RegionID","SizeRank","RegionName","RegionType","StateName","State","Metro","CountyName"],axis = 1)

# %%
data
# Out:
#         1996-01-31   1996-02-29   1996-03-31   1996-04-30   1996-05-31  \
# 0     209,351.0000 208,772.0000 208,472.0000 207,886.0000 207,651.0000
# 1     193,916.0000 193,960.0000 194,036.0000 194,196.0000 194,328.0000
# 2      95,454.0000  95,554.0000  95,560.0000  95,722.0000  95,882.0000
# 3     127,917.0000 127,789.0000 127,532.0000 127,497.0000 127,159.0000
# 4      94,992.0000  94,958.0000  94,925.0000  94,909.0000  94,846.0000
# 5      68,870.0000  68,782.0000  68,699.0000  68,554.0000  68,437.0000
# 6     101,612.0000 101,920.0000 102,253.0000 102,900.0000 103,517.0000
# 7     156,257.0000 156,112.0000 156,205.0000 156,188.0000 156,344.0000
# 8     216,701.0000 216,342.0000 216,098.0000 215,608.0000 215,316.0000
# 9      98,426.0000  98,471.0000  98,676.0000  99,038.0000  99,410.0000
# 10    189,467.0000 188,513.0000 186,912.0000 184,716.0000 184,409.0000
# 11    218,822.0000 218,222.0000 218,027.0000 217,717.0000 217,819.0000
# ...

# %%
for i in data.index:
    data.loc[i,"RegionID_SizeRank_RegionName_RegionType_StateName_State_Metro_CountyName"]= str(data.loc[i].RegionID)+str(data.loc[i].SizeRank)+str(data.loc[i].RegionName)+str(data.loc[i].RegionType)+str(data.loc[i].StateName)+str(data.loc[i].State)+str(data.loc[i].Metro)+str(data.loc[i].CountyName)

# %%
data
# Out:
#        RegionID  SizeRank       RegionName RegionType StateName State  \
# 0          6181         0         New York       City        NY    NY
# 1         12447         1      Los Angeles       City        CA    CA
# 2         39051         2          Houston       City        TX    TX
# 3         17426         3          Chicago       City        IL    IL
# 4          6915         4      San Antonio       City        TX    TX
# 5         13271         5     Philadelphia       City        PA    PA
# 6         40326         6          Phoenix       City        AZ    AZ
# 7         18959         7        Las Vegas       City        NV    NV
# 8         54296         8        San Diego       City        CA    CA
# 9         38128         9           Dallas       City        TX    TX
# 10        10221        10           Austin       City        TX    TX
# 11        33839        11         San Jose       City        CA    CA
# ...

# %% [markdown]
# ## Method 1

# %%
data = data.set_index(["RegionID","SizeRank","RegionName","RegionType","StateName","State","Metro","CountyName"])

# %%
data = data.transpose()

# %%
data
# Out:
# RegionID                        6181                           12447   \
# SizeRank                         0                              1
# RegionName                    New York                    Los Angeles
# RegionType                        City                           City
# StateName                           NY                             CA
# State                               NY                             CA
# Metro      New York-Newark-Jersey City Los Angeles-Long Beach-Anaheim
# CountyName               Queens County             Los Angeles County
# 1996-01-31                209,351.0000                   193,916.0000
# 1996-02-29                208,772.0000                   193,960.0000
# 1996-03-31                208,472.0000                   194,036.0000
# 1996-04-30                207,886.0000                   194,196.0000
# 1996-05-31                207,651.0000                   194,328.0000
# ...

# %%
mongod = mongo()
# Out:
# Connection Successful

# %%
mongod.conn.to_sql(data,database="Housing",table_name="Zillow_City")
# Out:
# If no error message, task completed
